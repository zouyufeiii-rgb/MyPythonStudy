# %% [markdown]
# # My first document.
# I am learning Python.

# %% [markdown]
# # Integer numbers

# %%
1+2
# Out:
# 3

# %%
15+25
# Out:
# 40

# %%
type(15)
# Out:
# int

# %%
type(111_222_333_444_555)
# Out:
# int

# %%
111_222_333_444_555
# Out:
# 111222333444555

# %% [markdown]
# ## Real numbers

# %%
1.
type(1.)
# Out:
# float

# %%
type(111_222_333_444_555.)
# Out:
# float

# %%
111_222_333_444_555789789789.
# Out:
# 1.1122233344455579e+23

# %%
1.5e6
# Out:
# 1500000.0

# %%
1.5e-6
# Out:
# 1.5e-06

# %%
10/7
# Out:
# 1.4285714285714286

# %%
10 // 7
#整数部分
# Out:
# 1

# %%
10 % 7
#余数部分
# Out:
# 3

# %% [markdown]
# ## Texts(strings)

# %%
'Statistics and data science with python'
# Out:
# 'Statistics and data science with python'

# %%
'"Statistics" and data science with python'
# Out:
# '"Statistics" and data science with python'

# %%
'''
This is a multi-line comment.
You can write anything here, and it will not affect the code execution.

'''
# Out:
# '\nThis is a multi-line comment.\nYou can write anything here, and it will not affect the code execution.\n\n'

# %%
'''This is a multi-line comment.
You can write anything here, and it will not affect the code execution.'''
# Out:
# 'This is a multi-line comment.\nYou can write anything here, and it will not affect the code execution.'

# %%
type('Hello')
# Out:
# str

# %%
'Hello' + 'World'
# Out:
# 'HelloWorld'

# %%
'Hello ' + 'World'
# Out:
# 'Hello World'

# %%
'Hello' + 3*' World'
# Out:
# 'Hello World World World'

# %% [markdown]
# # Variables

# %%
roomWidth = 10
roomLength = 15
roomArea = roomWidth * roomLength
roomArea
# Out:
# 150

# %%
roomWidth, roomLength = 20, 30
# a,b=b,a（可以互换位置）

# %%
cnt = 0
cnt
# Out:
# 0

# %%
cnt = cnt + 1 #等于 cnt += 1. 
# += -= *= /=
cnt
# Out:
# 1

# %% [markdown]
# # Logical

# %%
True
# Out:
# True

# %%
x=10

# %%
x>5
# Out:
# True

# %%
x<=10
# Out:
# True

# %%
x==10 #一个=是赋值，两个==是判断
# Out:
# True

# %%
x != 5 # different than
# Out:
# True

# %%
x > 5 and x < 15
# Out:
# True

# %%
x < 5 or x > 15
# Out:
# False

# %% [markdown]
# ## Lists

# %%
kcs = [2450,2100,2003,1001,1976]
kcs
# Out:
# [2450, 2100, 2003, 1001, 1976]

# %%
print(kcs)
# Out:
# [2450, 2100, 2003, 1001, 1976]

# %%
kcs[2] = 2009
kcs
# Out:
# [2450, 2100, 2009, 1001, 1976]

# %%
len(kcs)
# Out:
# 5

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
days
# Out:
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
a = ['Monday',2200]

# %% [markdown]
# # Tuples

# %%
days = ("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun")
days
# Out:
# ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')

# %%
type(days)
# Out:
# tuple

# %%
days[2]='TUESDAY'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 days[2]='TUESDAY'
#
# TypeError: 'tuple' object does not support item assignment

# %%
(1+2)*3
# Out:
# 9

# %%
1 # number one
(1) # number one
(1,) # tupke with one element
# Out:
# (1,)

# %%
x=() # an empty tuple
type(x)
# Out:
# tuple

# %% [markdown]
# # Accessing multiple list/tuple elements

# %%
kcs=[2450,2100,2200,1800,1900]

# %%
kcs[2:4]
# Out:
# [2200, 1800]

# %%
kcs[2:]
# Out:
# [2200, 1800, 1900]

# %%
kcs[:3]
# Out:
# [2450, 2100, 2200]

# %%
kcs[1:3]=[1,2]
kcs
# Out:
# [2450, 1, 2, 1800, 1900]

# %%
kcs[1:3]=[100,101,102,103,104,105]
kcs
# Out:
# [2450, 100, 101, 102, 103, 104, 105, 1800, 1900]

# %% [markdown]
# # Deep and shallow copy

# %%
v = [1,2,3]
v
# Out:
# [1, 2, 3]

# %%
w = v
w
# Out:
# [1, 2, 3]

# %%
v[0]=100
v
# Out:
# [100, 2, 3]

# %%
w #%% 与R不同
# Out:
# [100, 2, 3]

# %% [markdown]
# # List comprehensions

# %%
nums = [1,-2,3,-4,5]

# %%
[n*n for n in nums]
# Out:
# [1, 4, 9, 16, 25]

# %%
[n*n for n in nums if n > 0]
# Out:
# [1, 9, 25]
